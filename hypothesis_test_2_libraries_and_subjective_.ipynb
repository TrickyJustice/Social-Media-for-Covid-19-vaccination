# %%
import pandas as pd 
df1 = pd.read_csv('sl.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2331 non-null   int64
#  1   Unnamed: 0.1  2331 non-null   int64
#  2   date          2331 non-null   object
#  3   tweet         2331 non-null   object
#  4   language      2331 non-null   object
#  5   hashtags      2331 non-null   object
#  6   nlikes        2331 non-null   int64
#  7   nreplies      2331 non-null   int64
#  8   nlikes.1      2331 non-null   int64
#  9   nretweets     2331 non-null   int64
#  10  t             2331 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 200.4+ KB

# %%
pip install nltk

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
a = ''
c = sid.polarity_scores(a)

# %%
c
# Out:
# {'compound': 0.0, 'neg': 0.0, 'neu': 0.0, 'pos': 0.0}

# %%
c['compound']
# Out:
# 0.0

# %%
df1.info()
#df1 = df1.sort_values(by="date")
df1.date.head(500)
#df1.to_csv('ll.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2331 entries, 0 to 2330
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    2331 non-null   int64
#  1   Unnamed: 0.1  2331 non-null   int64
#  2   date          2331 non-null   object
#  3   tweet         2331 non-null   object
#  4   language      2331 non-null   object
#  5   hashtags      2331 non-null   object
#  6   nlikes        2331 non-null   int64
#  7   nreplies      2331 non-null   int64
#  8   nlikes.1      2331 non-null   int64
#  9   nretweets     2331 non-null   int64
#  10  t             2331 non-null   int64
# dtypes: int64(7), object(4)
# memory usage: 200.4+ KB
# 0      04/03/2021 15:15
# 1      04/03/2021 15:01
# 2      04/03/2021 11:18
# 3      03/03/2021 21:35
# 4       25/02/2021 7:45
#              ...
# 495     27/02/2021 9:49
# 496     27/02/2021 8:51
# 497     27/02/2021 8:46
# 498     27/02/2021 8:40
# ...

# %%
df1['date'] = df1['date'].map(lambda x: x[0:10])

# %%
category =[]
for i in range(2331):
  if(df1['date'][i]=='25/02/2021'):
    category.append(1)
  if(df1['date'][i]=='26/02/2021'):
    category.append(2)
  if(df1['date'][i]=='27/02/2021'):
    category.append(3)
  if(df1['date'][i]=='28/02/2021'):
    category.append(4)
  if(df1['date'][i]=='01/03/2021'):
    category.append(5)
  if(df1['date'][i]=='02/03/2021'):
    category.append(6)
  if(df1['date'][i]=='03/03/2021'):
    category.append(7)
  if(df1['date'][i]=='04/03/2021'):
    category.append(8)
  if(df1['date'][i]=='05/03/2021'):
    category.append(9)
df1['category'] = category

# %%
for i in range(2331):
  if(df1['date'][i]=='25/02/2021'):
    df1['category'][i] = 1
  if(df1['date'][i]=='26/02/2021'):
    df1['category'][i] = 2
  if(df1['date'][i]=='27/02/2021'):
    df1['category'][i] = 3
  if(df1['date'][i]=='28/02/2021'):
    df1['category'][i] = 4
  if(df1['date'][i]=='01/03/2021'):
    df1['category'][i] = 5
  if(df1['date'][i]=='02/03/2021'):
    df1['category'][i] = 6
  if(df1['date'][i]=='03/03/2021'):
    df1['category'][i] = 7
  if(df1['date'][i]=='04/03/2021'):
    df1['category'][i] = 8
  if(df1['date'][i]=='05/03/2021'):
    df1['category'][i] = 9

df1 = df1.sort_values(by="category")
df1.head(50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1.category
data =[]
n_of_tweet=[]
nek = []

# %%
df3 = pd.DataFrame(columns=['netsenti','date','notweet'])

# %%
df3
# Out:
# Empty DataFrame
# Columns: [netsenti, date, notweet]
# Index: []

# %%
for i in range(1,10):
  sum=0;
  for j in range (2331):
    if(df1['category'][j]==i):
      a = df1['tweet'][j]
      c = sid.polarity_scores(a)
      sum = sum + c['compound']
  data.append(sum)

# %%
data
# Out:
# [14.1053,
#  33.40739999999999,
#  22.2413,
#  11.445599999999997,
#  136.79439999999997,
#  50.07639999999997,
#  34.18480000000002,
#  48.94679999999996,
#  4.2945]

# %%
df3['netsenti']=data
dates = [ '25/02/2021','26/02/2021','27/02/2021','28/02/2021','01/03/2021','02/03/2021','03/03/2021','04/03/2021','05/03/2021']
df3['date']=dates

# %%
df3['netsenti1']=0
df3
# Out:
#    netsenti        date notweet  netsenti1
# 0   14.1053  25/02/2021     NaN          0
# 1   33.4074  26/02/2021     NaN          0
# 2   22.2413  27/02/2021     NaN          0
# 3   11.4456  28/02/2021     NaN          0
# 4  136.7944  01/03/2021     NaN          0
# 5   50.0764  02/03/2021     NaN          0
# 6   34.1848  03/03/2021     NaN          0
# 7   48.9468  04/03/2021     NaN          0
# 8    4.2945  05/03/2021     NaN          0

# %%
from textblob import TextBlob
data4=[]

# %%
for i in range(1,10):
  sum=0;
  for j in range (2331):
    if(df1['category'][j]==i):
      a = df1['tweet'][j]
      c = TextBlob(a)
      sum = sum + c.polarity
  data4.append(sum)
df3['netsenti1'] =data4

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
x ,y  = dates,df3['netsenti']
plt.figure(figsize=(10,3))
plt.plot(x,y)

# %%
df3
# Out:
#    netsenti        date notweet   netsenti1
# 0   14.1053  25/02/2021     NaN   17.637363
# 1   33.4074  26/02/2021     NaN   16.571446
# 2   22.2413  27/02/2021     NaN   19.977341
# 3   11.4456  28/02/2021     NaN   10.145142
# 4  136.7944  01/03/2021     NaN  105.545475
# 5   50.0764  02/03/2021     NaN   44.792115
# 6   34.1848  03/03/2021     NaN   31.065659
# 7   48.9468  04/03/2021     NaN   40.556214
# 8    4.2945  05/03/2021     NaN    1.938001

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
x ,y  = dates,df3['netsenti1']
plt.figure(figsize=(10,3))
plt.plot(x,y)

# %%
pip install text2emotion

# %%
import text2emotion as te
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
c = "Sir this is one of the worldâ€™s biggest vaccination drive.I understand there are roadblocks but people are not able to get the dose. Online registration not working private hospitals are denying vaccine to walkin, even those who got their 1st shot in January are denied second dose"

# %%
l=te.get_emotion(c)
l
# Out:
# {'Angry': 0.0, 'Fear': 0.5, 'Happy': 0.0, 'Sad': 0.5, 'Surprise': 0.0}

# %%
df3
# Out:
#    netsenti        date notweet
# 0   14.1053  25/02/2021     NaN
# 1   33.4074  26/02/2021     NaN
# 2   22.2413  27/02/2021     NaN
# 3   11.4456  28/02/2021     NaN
# 4  136.7944  01/03/2021     NaN
# 5   50.0764  02/03/2021     NaN
# 6   34.1848  03/03/2021     NaN
# 7   48.9468  04/03/2021     NaN
# 8    4.2945  05/03/2021     NaN

# %%
#l['Sad']
sada=[]
happya=[]
feara=[]
surprisea=[]
angrya=[]

# %%
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1        date  ... nretweets   t category
# 2330        2330          2366  25/02/2021  ...         0  11        1
# 2125        2125          2155  25/02/2021  ...         1  37        1
# 2124        2124          2154  25/02/2021  ...         0   4        1
# 2123        2123          2153  25/02/2021  ...         0  29        1
# 2122        2122          2152  25/02/2021  ...         0  10        1
# ...          ...           ...         ...  ...       ...  ..      ...
# 879          879           892  05/03/2021  ...         0  10        9
# 1426        1426          1451  05/03/2021  ...         0   5        9
# 1425        1425          1450  05/03/2021  ...         0  48        9
# 2142        2142          2172  05/03/2021  ...         0   7        9
# 1424        1424          1449  05/03/2021  ...         0  43        9
#
# [2331 rows x 12 columns]

# %%
print(sada)
# Out:
# []

# %%
for i in range(1,10):
  sad=0
  happy=0
  fear=0
  surprise=0
  angry=0
  for j in range (2331):
    if(df1['category'][j]==i):
      c=df1['tweet'][j]
      l=te.get_emotion(c)
      sad=sad+l['Sad']
      happy=happy+l['Happy']
      fear=fear+l['Fear']
      surprise=surprise+l['Surprise']
      angry=angry+l['Angry']
      
  sada.append(sad)
  happya.append(happy)
  feara.append(fear)
  surprisea.append(surprise)
  angrya.append(angry)

# %%
sada
# Out:
# [23.74999999999999,
#  25.379999999999992,
#  31.149999999999988,
#  27.469999999999988,
#  97.04000000000002,
#  63.77000000000002,
#  49.07999999999999,
#  45.109999999999985,
#  1.32]

# %%
df3['sad']=sada
notweet=[]

# %%
df3
# Out:
#    netsenti        date notweet    sad
# 0   14.1053  25/02/2021     NaN  23.75
# 1   33.4074  26/02/2021     NaN  25.38
# 2   22.2413  27/02/2021     NaN  31.15
# 3   11.4456  28/02/2021     NaN  27.47
# 4  136.7944  01/03/2021     NaN  97.04
# 5   50.0764  02/03/2021     NaN  63.77
# 6   34.1848  03/03/2021     NaN  49.08
# 7   48.9468  04/03/2021     NaN  45.11
# 8    4.2945  05/03/2021     NaN   1.32

# %%
for i in range(1,10):
  sum=0;
  for j in range (2331):
    if(df1['category'][j]==i):
      sum = sum + 1
  notweet.append(sum)

# %%
df3['notweet']=notweet

# %%
df3
# Out:
#    netsenti        date  notweet    sad
# 0   14.1053  25/02/2021      166  23.75
# 1   33.4074  26/02/2021      157  25.38
# 2   22.2413  27/02/2021      161  31.15
# 3   11.4456  28/02/2021      132  27.47
# 4  136.7944  01/03/2021      708  97.04
# 5   50.0764  02/03/2021      411  63.77
# 6   34.1848  03/03/2021      283  49.08
# 7   48.9468  04/03/2021      299  45.11
# 8    4.2945  05/03/2021       14   1.32

# %%
df3['happy']=happya
df3['angry']=angrya
df3['surprise']=surprisea
df3['fear']=feara

# %%
df3
# Out:
#    netsenti        date  notweet  ...  avg_angry  avg_fear  avg_surprise
# 0   14.1053  25/02/2021      166  ...          0         0             0
# 1   33.4074  26/02/2021      157  ...          0         0             0
# 2   22.2413  27/02/2021      161  ...          0         0             0
# 3   11.4456  28/02/2021      132  ...          0         0             0
# 4  136.7944  01/03/2021      708  ...          0         0             0
# 5   50.0764  02/03/2021      411  ...          0         0             0
# 6   34.1848  03/03/2021      283  ...          0         0             0
# 7   48.9468  04/03/2021      299  ...          0         0             0
# 8    4.2945  05/03/2021       14  ...          0         0             0
#
# [9 rows x 13 columns]

# %%
df3['a_sad']=np.nan
df3['a_happy']=np.nan
df3['a_angry']=np.nan
df3['a_fear']=np.nan
df3['a_surprise']=np.nan

# %%
df3
# Out:
#    netsenti        date  notweet  ...  a_fear  av_surprise  a_surprise
# 0   14.1053  25/02/2021      166  ...     NaN            0         NaN
# 1   33.4074  26/02/2021      157  ...     NaN            0         NaN
# 2   22.2413  27/02/2021      161  ...     NaN            0         NaN
# 3   11.4456  28/02/2021      132  ...     NaN            0         NaN
# 4  136.7944  01/03/2021      708  ...     NaN            0         NaN
# 5   50.0764  02/03/2021      411  ...     NaN            0         NaN
# 6   34.1848  03/03/2021      283  ...     NaN            0         NaN
# 7   48.9468  04/03/2021      299  ...     NaN            0         NaN
# 8    4.2945  05/03/2021       14  ...     NaN            0         NaN
#
# [9 rows x 19 columns]

# %%
for i in range(9):
  df3['a_sad'][i] = df3.sad[i]/df3.notweet[i]
  df3['a_happy'][i]=df3.happy[i]/df3.notweet[i]
  df3['a_angry'][i]=df3.angry[i]/df3.notweet[i]
  df3['a_fear'][i]=df3.fear[i]/df3.notweet[i]
  df3['a_surprise'][i]=df3.surprise[i]/df3.notweet[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df3
# Out:
#    netsenti        date  notweet  ...    a_fear  av_surprise  a_surprise
# 0   14.1053  25/02/2021      166  ...  0.348675            0    0.208072
# 1   33.4074  26/02/2021      157  ...  0.350573            0    0.147771
# 2   22.2413  27/02/2021      161  ...  0.223043            0    0.249006
# 3   11.4456  28/02/2021      132  ...  0.285985            0    0.181364
# 4  136.7944  01/03/2021      708  ...  0.281045            0    0.322161
# 5   50.0764  02/03/2021      411  ...  0.315596            0    0.253528
# 6   34.1848  03/03/2021      283  ...  0.360742            0    0.172792
# 7   48.9468  04/03/2021      299  ...  0.257157            0    0.253946
# 8    4.2945  05/03/2021       14  ...  0.227143            0    0.065714
#
# [9 rows x 19 columns]

# %%
df3.drop(columns=['avg_sad','avg_happy','avg_surprise','avg_fear','avg_angry','av_surprise'],axis=1)
# Out:
#    netsenti        date  notweet  ...   a_angry    a_fear  a_surprise
# 0   14.1053  25/02/2021      166  ...  0.029940  0.348675    0.208072
# 1   33.4074  26/02/2021      157  ...  0.040318  0.350573    0.147771
# 2   22.2413  27/02/2021      161  ...  0.031491  0.223043    0.249006
# 3   11.4456  28/02/2021      132  ...  0.040758  0.285985    0.181364
# 4  136.7944  01/03/2021      708  ...  0.035960  0.281045    0.322161
# 5   50.0764  02/03/2021      411  ...  0.028321  0.315596    0.253528
# 6   34.1848  03/03/2021      283  ...  0.028657  0.360742    0.172792
# 7   48.9468  04/03/2021      299  ...  0.017625  0.257157    0.253946
# 8    4.2945  05/03/2021       14  ...  0.024286  0.227143    0.065714
#
# [9 rows x 13 columns]

# %%
c="2nd Dose Vaccine Complete..  Gov. Of india and Indian Scientist.. Vaccination."
l=te.get_emotion(c)
l
# Out:
# {'Angry': 0, 'Fear': 0, 'Happy': 0, 'Sad': 0, 'Surprise': 0}

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
x ,y  = dates,df3['a_surprise']
plt.figure(figsize=(10,3))
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
x ,y  = dates,df3['sad']
plt.figure(figsize=(10,3))
plt.plot(x,y)
