# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('gdrive/MyDrive/researchProjectIME/patna_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        date  ... jugaad dates
# 0           0  14/05/2021  ...    514    30
# 1           1  14/05/2021  ...    514    30
# 2           2  14/05/2021  ...    514    30
# 3           3  14/05/2021  ...    514    30
# 4           4  14/05/2021  ...    514    30
#
# [5 rows x 16 columns]

# %%
df_dictionary = pd.read_csv('gdrive/MyDrive/researchProjectIME/data_dictionary.csv')
df_dictionary.head()
# Out:
#       making
# 0     supply
# 1  increased
# 2    exceeds
# 3  resisting
# 4    refused

# %%
keywords = []
for word in df_dictionary.making:
  keywords.append(word)

# %%
keywords
# Out:
# ['supply',
#  'increased',
#  'exceeds',
#  'resisting',
#  'refused',
#  'created',
#  'demand',
#  'grant',
#  'repeating',
#  'press',
#  'paid',
#  'diminish',
#  'concede',
#  'caused',
#  'accepts',
#  'stating',
#  'occasioned',
#  'lays',
#  'fulfil',
#  'brought',
#  'suit',
#  'rejected',
#  'lessens',
#  'considering',
#  'hearing',
#  'followed',
#  'decrease',
#  'come',
#  'anticipating',
#  'yielded',
#  'withdrew',
#  'urged',
#  'stimulating',
#  'renewed',
#  'reiterated',
#  'reduce',
#  'raise',
#  'prevent',
#  'present',
#  'obtain',
#  'modify',
#  'moderate',
#  'justify',
#  'evade',
#  'escape',
#  'constitute',
#  'carry',
#  'affect',
#  'underlying',
#  'touching',
#  'suppose',
#  'silence',
#  'show',
#  'see',
#  'seconding',
#  'save',
#  'revive',
#  'regard',
#  'read',
#  'produce',
#  'prefer',
#  'point',
#  'please',
#  'obey',
#  'neglect',
#  'need',
#  'limit',
#  'like',
#  'issue',
#  'involve',
#  'imply',
#  'honor',
#  'heeded',
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        date  ... jugaad dates
# 0           0  14/05/2021  ...    514    30
# 1           1  14/05/2021  ...    514    30
# 2           2  14/05/2021  ...    514    30
# 3           3  14/05/2021  ...    514    30
# 4           4  14/05/2021  ...    514    30
#
# [5 rows x 16 columns]

# %%
df['frequency']=0
for word in keywords:
  df['frequency'] += df['tweet'].map(lambda x: x.count(word))

# %%
df.head()
size=df.shape[0]

# %%
sum=[]
for i in range(31):
  s=0
  for j in range(size):
    if(df['dates'][j]==i):
      s=s+df['frequency'][j]
  sum.append(s)

# %%
sum
# Out:
# [37,
#  67,
#  48,
#  118,
#  96,
#  89,
#  90,
#  122,
#  104,
#  92,
#  120,
#  130,
#  163,
#  122,
#  234,
#  176,
#  95,
#  116,
#  66,
#  115,
#  150,
#  227,
#  175,
#  180,
#  104,
#  277,
#  185,
#  765,
#  1715,
#  1067,
#  752]

# %%
import datetime

# %%
start_date = datetime.date(2021, 4, 14)
end_date = datetime.date(2021,5,14)
delta = datetime.timedelta(days=1)
date=[]
while start_date <= end_date:
    print(start_date)
    date.append(start_date)
    start_date += delta
# Out:
# 2021-04-14
# 2021-04-15
# 2021-04-16
# 2021-04-17
# 2021-04-18
# 2021-04-19
# 2021-04-20
# 2021-04-21
# 2021-04-22
# 2021-04-23
# 2021-04-24
# 2021-04-25
# 2021-04-26
# 2021-04-27
# 2021-04-28
# 2021-04-29
# 2021-04-30
# 2021-05-01
# 2021-05-02
# 2021-05-03
# 2021-05-04
# 2021-05-05
# 2021-05-06
# 2021-05-07
# 2021-05-08
# 2021-05-09
# 2021-05-10
# 2021-05-11
# 2021-05-12
# 2021-05-13
# 2021-05-14

# %%
final=pd.DataFrame(columns=["date","freq"])
final['date'] = date
final['freq'] = sum

# %%
final
#final.drop(i,axis=0,inplace=True)
# Out:
#           date  freq
# 0   2021-04-14    37
# 1   2021-04-15    67
# 2   2021-04-16    48
# 3   2021-04-17   118
# 4   2021-04-18    96
# 5   2021-04-19    89
# 6   2021-04-20    90
# 7   2021-04-21   122
# 8   2021-04-22   104
# 9   2021-04-23    92
# 10  2021-04-24   120
# 11  2021-04-25   130
# 12  2021-04-26   163
# 13  2021-04-27   122
# 14  2021-04-28   234
# 15  2021-04-29   176
# 16  2021-04-30    95
# 17  2021-05-01   116
# 18  2021-05-02    66
# 19  2021-05-03   115
# 20  2021-05-04   150
# 21  2021-05-05   227
# 22  2021-05-06   175
# 23  2021-05-07   180
# 24  2021-05-08   104
# 25  2021-05-09   277
# 26  2021-05-10   185
# 27  2021-05-11   765
# 28  2021-05-12  1715
# 29  2021-05-13  1067
# 30  2021-05-14   752

# %%
import numpy as np
import matplotlib.pyplot as plt
x=final.date
y=final.freq
plt.figure(figsize=(20,30))
plt.plot(x,y)

# %%
vaccinated_df= pd.read_csv('gdrive/MyDrive/researchProjectIME/patna_daywise.csv')

# %%
vaccinated_df
# Out:
#    |__vaccine_date  |__total  |__dose_1  |__dose_2
# 0       15/04/2021     15531      12326       3205
# 1       16/04/2021     13542      10436       3106
# 2       17/04/2021     13442      10834       2608
# 3       18/04/2021      5240       4527        713
# 4       19/04/2021     11775       7350       4425
# 5       20/04/2021      9261       6532       2729
# 6       21/04/2021      7182       4991       2191
# 7       22/04/2021     11009       5956       5053
# 8       23/04/2021      9248       6221       3027
# 9       24/04/2021      8889       6188       2701
# 10      25/04/2021      3221       2770        451
# 11      26/04/2021     11686       6032       5654
# 12      27/04/2021      8265       5240       3025
# 13      28/04/2021      7451       4503       2948
# 14      29/04/2021     12071       5554       6517
# 15      30/04/2021      9829       5377       4452
# 16      01/05/2021      7069       3815       3254
# ...

# %%
vaccinated_df['|__vaccine_date'][0] 
kk=[]
final['vaccinated1']=0
final['freq11']=0

# %%
kk=[]
kk.append(5000)
kk.append(5000)
kk.append(5000)
kk.append(5000)
for  i in range(3,30):
  kk.append(vaccinated_df['|__total'][i])
kk
# Out:
# [5000,
#  5000,
#  5000,
#  5000,
#  5240,
#  11775,
#  9261,
#  7182,
#  11009,
#  9248,
#  8889,
#  3221,
#  11686,
#  8265,
#  7451,
#  12071,
#  9829,
#  7069,
#  2982,
#  8743,
#  7442,
#  6411,
#  11020,
#  6747,
#  6031,
#  4888,
#  15821,
#  12290,
#  13360,
#  19023,
#  16663]

# %%
final['vaccinated']=kk
final
# Out:
#           date  freq  vaccinated  vaccinated1  freq1
# 0   2021-04-14    37        5000         5000     37
# 1   2021-04-15    67        5000         5000     67
# 2   2021-04-16    48        5000         5000     48
# 3   2021-04-17   118        5000         5000    118
# 4   2021-04-18    96        5240         5240     96
# 5   2021-04-19    89       11775        11775     89
# 6   2021-04-20    90        9261         9261     90
# 7   2021-04-21   122        7182         7182    122
# 8   2021-04-22   104       11009        11009    104
# 9   2021-04-23    92        9248         9248     92
# 10  2021-04-24   120        8889         8889    120
# 11  2021-04-25   130        3221         3221    130
# 12  2021-04-26   163       11686        11686    163
# 13  2021-04-27   122        8265         8265    122
# 14  2021-04-28   234        7451         7451    234
# 15  2021-04-29   176       12071        12071    176
# 16  2021-04-30    95        9829         9829     95
# ...

# %%
a=4
b=3
c=3/4
ma=[]
for i in range(31):
  c=(final['vaccinated'][i]-2500)/(19023-2500)
  final['vaccinated1'][i]=c
  m=(final['freq'][i]-30)/(1715-30)
  ma.append(m)
final['freq1']=ma
final
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#           date  freq  vaccinated  vaccinated1     freq1
# 0   2021-04-14    37        5000     0.151304  0.004154
# 1   2021-04-15    67        5000     0.151304  0.021958
# 2   2021-04-16    48        5000     0.151304  0.010682
# 3   2021-04-17   118        5000     0.151304  0.052226
# 4   2021-04-18    96        5240     0.165829  0.039169
# 5   2021-04-19    89       11775     0.561339  0.035015
# 6   2021-04-20    90        9261     0.409187  0.035608
# 7   2021-04-21   122        7182     0.283363  0.054599
# 8   2021-04-22   104       11009     0.514979  0.043917
# 9   2021-04-23    92        9248     0.408400  0.036795
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(40,10))
x1 = final['date']
y1 = final['vaccinated1']
# plotting the line 1 points 

plt.plot(x1, y1, label = "vaccianted")
# line 2 points
x2 = final['date']
y2 = final['freq1']
# plotting the line 2 points 
plt.plot(x2, y2, label = "freq")
plt.xlabel('x - axis')
# Set the y axis label of the current axis.
plt.ylabel('y - axis')
# Set a title of the current axes.
plt.title(' comparitive ')

# show a legend on the plot
plt.legend()

# Display a figure.
plt.show()
