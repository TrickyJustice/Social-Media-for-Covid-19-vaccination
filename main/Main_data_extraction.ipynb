# %%
# !pip list | grep -w twint || pip install --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /tmp/pip-install-bcjzt4hw/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /tmp/pip-install-bcjzt4hw/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
# ...
#      |████████████████████████████████| 1.3MB 4.0MB/s
# ...
#      |████████████████████████████████| 266kB 28.4MB/s
# ...
#      |████████████████████████████████| 348kB 23.1MB/s
# ...
#      |████████████████████████████████| 143kB 30.6MB/s
# ...
#      |████████████████████████████████| 296kB 24.0MB/s
# ...
#      |████████████████████████████████| 296kB 21.9MB/s
# ...
#   Created wheel for twint: filename=twint-2.1.21-cp37-none-any.whl size=38863 sha256=148de67e9779777888f79609276571228b58d13c3ad738e62987c41f98f2c4fb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bxcjh2y7/wheels/4f/3b/75/62d04b3b446658ba85401e8868d3cd1d4bc22f17ad755460a6
# ...

# %%
import twint

# %%
import pandas as pd

# extract data from twitter 
import twint

##Solve compatibility issues with notebooks and RunTime errors
import nest_asyncio
nest_asyncio.apply()

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "anil vij"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.7196,75.8577"
c.Since = "2021-01-16"
c.Until = "2021-04-15"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
df2 = twint.storage.panda.Tweets_df

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               69 non-null     object
#  1   conversation_id  69 non-null     object
#  2   created_at       69 non-null     float64
#  3   date             69 non-null     object
#  4   timezone         69 non-null     object
#  5   place            69 non-null     object
#  6   tweet            69 non-null     object
#  7   language         69 non-null     object
#  8   hashtags         69 non-null     object
#  9   cashtags         69 non-null     object
#  10  user_id          69 non-null     int64
#  11  user_id_str      69 non-null     object
#  12  username         69 non-null     object
#  13  name             69 non-null     object
#  14  day              69 non-null     int64
#  15  hour             69 non-null     object
#  16  link             69 non-null     object
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "dose"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)
# Out:
# 1370700069800873985 2021-03-13 11:35:37 +0000 <JaiBharathi> When a daughter encourages her mother who wants to follow her passion of riding motorcycles! Pictures like these are my daily dose of inspiration 😊
# 1370540733933875201 2021-03-13 01:02:29 +0000 <HariOm1Care> Dereliction of duty, How much time dose Bmc needs to pull down the banners once notified, Bmc staff should suo moto keep Survillience alternative day in the territory not been done @IqbalSinghChah2  @CPMumbaiPolice  @CMOMaharashtra
# 1370382684317315079 2021-03-12 14:34:27 +0000 <Insight_neel> I chose to be protected by 50% than no protection at all.  Someone said “Posting on social media is equally important after Vaccination for larger impact”.  First dose done.  #vaccinated #Inspire_Lives  https://t.co/tVxFK5lMz0
# ...

# %%
df3 = twint.storage.panda.Tweets_df

# %% [markdown]
# df3.info()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               45 non-null     object
#  1   conversation_id  45 non-null     object
#  2   created_at       45 non-null     float64
#  3   date             45 non-null     object
#  4   timezone         45 non-null     object
#  5   place            45 non-null     object
#  6   tweet            45 non-null     object
#  7   language         45 non-null     object
#  8   hashtags         45 non-null     object
#  9   cashtags         45 non-null     object
#  10  user_id          45 non-null     int64
#  11  user_id_str      45 non-null     object
#  12  username         45 non-null     object
#  13  name             45 non-null     object
#  14  day              45 non-null     int64
#  15  hour             45 non-null     object
#  16  link             45 non-null     object
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "serum institute of india"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)
# Out:
# 1369188313412689920 2021-03-09 07:28:26 +0000 <FRcdu> Here's the 12th edition of Finkosh which exclusively covers surging petrol prices, privatisation of PSUs, the story of RailTel, the cryptocurrency, and Serum Institute of India! For legends of DU, we have Kanak Gussain.   Click the link below to read!  https://t.co/boYe4kWtDZ  https://t.co/XkLXt2FECE
# 1368388167569612802 2021-03-07 02:28:57 +0000 <Raghuveer814155> UK will receive 10 million AstraZeneca COVID19 🇮🇳 vaccine doses made by the Serum Institute of India   #OurVaccineOurPride।।  https://t.co/aWL4w9hija
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
df4 = twint.storage.panda.Tweets_df

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2 non-null      object
#  1   conversation_id  2 non-null      object
#  2   created_at       2 non-null      float64
#  3   date             2 non-null      object
#  4   timezone         2 non-null      object
#  5   place            2 non-null      object
#  6   tweet            2 non-null      object
#  7   language         2 non-null      object
#  8   hashtags         2 non-null      object
#  9   cashtags         2 non-null      object
#  10  user_id          2 non-null      int64
#  11  user_id_str      2 non-null      object
#  12  username         2 non-null      object
#  13  name             2 non-null      object
#  14  day              2 non-null      int64
#  15  hour             2 non-null      object
#  16  link             2 non-null      object
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "adar poonawalla"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df5 = twint.storage.panda.Tweets_df
df5.info()
# Out:
# 1370760949611720709 2021-03-13 15:37:32 +0000 <h_lokhandwala> Thanks @mygovindia @adarpoonawalla.. My father got 1st dose of CoVID19 vaccination  https://t.co/3kvR368F90
# 1370690432292716546 2021-03-13 10:57:19 +0000 <sahani_08> Don’t ask to take your f***ng loans ...we are already under debt of our previous loans...why the hell you can’t go for a mass vaccination...@adarpoonawalla ..or u want to serve only one industry today which is pharma and hospitals...?
# 1370595459559985153 2021-03-13 04:39:56 +0000 <ashish9191> @narendramodi @adarpoonawalla @PMCPune  What an irony, the city which produces Covid-19 vaccine has highest no. of patients admitted in the country.  Does people lack common sense or does administration needs professionalism ?  A lot of efforts are required to aware people.
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "covaxin"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df6 = twint.storage.panda.Tweets_df
df6.info()
# Out:
# 1370781923618947075 2021-03-13 17:00:53 +0000 <mahek108> @KiranKS Covieshield &amp; Covaxin efficacy yet to be proved against Brazilian, South African and UK variants. Which may put us all in big trouble again.
# 1370675273838993412 2021-03-13 09:57:05 +0000 <SirbhuvneshJi> #2nd #Dose of #COVAXIN #Successful  https://t.co/zT8dgoEOib
# 1370658393132691457 2021-03-13 08:50:01 +0000 <avinashsingh101> आज मेरी माता जी ने  सदर अस्पताल में भारत में निर्मित #CoVaxin की अपनी पहली डोज़ लगवाई। कोराना बचाव हेतु वैक्सीन अवश्य लगवाएं l आप भी शीघ्र अति शीघ्र वैक्सीन लगवाएं खुद भी सुरक्षित रहें औरों को भी सुरक्षित रखें🙏🏻🙏🏻  हॉस्पिटल के डॉक्टर एवं स्टाफ को सादर आभार ।।  https://t.co/NDXuvBvUeC
# 1370454619499888640 2021-03-12 19:20:17 +0000 <mahek108> @JamesKosur @g2hmtweet What about Astrazeneca and Covaxin?
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "pfizer"
c.Lang = "english"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df7 = twint.storage.panda.Tweets_df
df7.info()
# Out:
# 1370583070227718151 2021-03-13 03:50:42 +0000 <AkhtarS33360469> Safety ranking NY Times 5-2-2021 Reports:  *1. Sinopharm (China)*  *2. Sinovac (China)*  *3. Kexing (China)*  *4. Can Sino (China)*  5. AstraZeneca (UK)  6. Pfizer (USA &amp; Germany)  7. Modena (USA)  8. Johnson &amp; Johnson (USA)  9. Novavax (United States)  10. Satellite 5 (Russia)
# 1370017662856622085 2021-03-11 14:23:59 +0000 <shantanughosh> Real world data shows Pfizer efficacy at 97%. Wow! Unfortunately, not a priority for India given its high price. #vaccine
# 1369348731452133377 2021-03-09 18:05:53 +0000 <seshanm> #AmericaMessesUp  Americans can get nothing right it seems.   In the most recent incident, more than 4000 people received around 0.2 ml of the vaccine instead of the optimal vaccine dosage of 0.3 ml of Pfizer.  @washingtonpost  @nytimes
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "aiims"
c.Lang = "english"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df8 = twint.storage.panda.Tweets_df
df8.info()
# Out:
# 1370826808870924288 2021-03-13 19:59:14 +0000 <aiims_pharmacy> #pharmacy franchise  https://t.co/UXMSvURASp
# 1370799423131910144 2021-03-13 18:10:25 +0000 <KunalTh84869863> @aiims_rpr @aiims_newdelhi @AIIMSBhopal @akshaykumar
# 1370765332919427074 2021-03-13 15:54:57 +0000 <DirectorAtAIIMS> Minister Visits AIIMS, Bhopal. Half a dozen more Covid-19 vaccines soon: Dr Harsh Vardhan | India News - Times of India  https://t.co/a7CYeRkqyP
# 1370735934308769808 2021-03-13 13:58:08 +0000 <_dilli6onwheels> Ghar Jaisa Khana  Meal Combos @Rs.100/- Only #dilli6onwheels  #dilli6onwheels_jiasarai  Order Online:  #Swiggy &amp; #zomato  #reliancejio #amazonindia #medanta #gurugram #instagram #twitter #facebook #googleindia #google #delhiuniversity #aiims #dipsacademy #lalajispg #iitdelhi  https://t.co/u1xdL3DI0w
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "frontline"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df9 = twint.storage.panda.Tweets_df
df9.info()
# Out:
# 1370757148800520193 2021-03-13 15:22:26 +0000 <brishtirnuri> Shouldn’t schoolteachers and academicians who are compelled to work offline deserve vaccination in the frontline category? #covidsurge
# 1370063030302601216 2021-03-11 17:24:15 +0000 <BollamRajesh4> The combination of nivolumab and cabozantinib showcased significant benefit in terms of PFS, OS, and responses vs sunitinib in the frontline treatment of patients with advanced RCC. @DanaFarber #kcsm  https://t.co/Ccd70SuQRC
# 1370047656471318536 2021-03-11 16:23:10 +0000 <BiswalSouvic> Commend the hard work and dedication of our frontline #CovidWarriors for successfully administering more than 10 lakh doses of vaccine to healthcare workers, frontline workers &amp; elderly citizens in just 45 days. #OdishaCares❤️  #LargestVaccineDrive 💉   https://t.co/UIitBOxzPL
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search=
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "vaccination"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df13 = twint.storage.panda.Tweets_df
df13.info()
# Out:
# 1370786593980620800 2021-03-13 17:19:26 +0000 <Drvilasjagdale> @CMOMaharashtra @rajeshtope11 @AnilDeshmukhNCP @advanilparab @AmitV_Deshmukh @NANA_PATOLE @RajThackeray @PawarSpeaks @supriya_sule @SerumInstIndia I am 2 step forward establish #vaccinecourt then I will talk I am standing here against mandatory Vaccination @PMOIndia @RahulGandhi  https://t.co/MSCfTqiSRY
# 1370775758411497481 2021-03-13 16:36:23 +0000 <VeerPatilRaikod> @BJP4Karnataka General Secretary &amp; yuva morcha prabhari shri @MTenginkai ji took a virtual meeting regarding covid #vaccination awareness in districts as @narendramodi ji aims to serve his services to every citizen of india.  @DrSandeepBJYM ji @DrmallikarjunB3 ji 🙏  https://t.co/O7IF2mWPBq
# ...

# %%
c= twint.Config()

# extracting data from twitter

c.Search= "testing"
c.Pandas= True
c.Limit= 10000
c.Geo = "22.3072,73.1812,400mi"
c.Since = "2021-03-05"
c.Until = "2021-03-14"
c.Store_csv = True
c.output = "scrapped data.csv"
twint.run.Search(c)

df14 = twint.storage.panda.Tweets_df
df14.info()
# Out:
# 1370856747628326913 2021-03-13 21:58:12 +0000 <Pareshmadan06> @zomatoin @zomato @zomatocare  Seems as if you really are testing the patience of the citizens Would you wanna reply to the mail or do you want all of us to show you the power of the citizens ? Reply at the earliest #zomatodeliveryboy #kamaraj
# 1370843227058700289 2021-03-13 21:04:29 +0000 <rupeshmalpani> @ElonAccessories testing!
# 1370775684591718402 2021-03-13 16:36:05 +0000 <BollamRajesh4> Great paper led by @DrRaviSalgia w @dave6408 &amp; @ACCCBuzz highlighting benefits of an MDT approach on (1) screening, (2) staging &amp; (3) molecular testing in @ASCO_pubs @JOP_ASCO. Supports approach taken by our esteemed group at @cityofhope!   https://t.co/EvLkeOoJaU
# ...

# %%
frames = [df3,df4,df5,df6,df8,df9,df10,df11,df12,df13,df14]
combined_df = pd.concat(frames)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 0 to 52
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               743 non-null    object
#  1   conversation_id  743 non-null    object
#  2   created_at       743 non-null    float64
#  3   date             743 non-null    object
#  4   timezone         743 non-null    object
#  5   place            743 non-null    object
#  6   tweet            743 non-null    object
#  7   language         743 non-null    object
#  8   hashtags         743 non-null    object
#  9   cashtags         743 non-null    object
#  10  user_id          743 non-null    int64
#  11  user_id_str      743 non-null    object
#  12  username         743 non-null    object
#  13  name             743 non-null    object
#  14  day              743 non-null    int64
#  15  hour             743 non-null    object
#  16  link             743 non-null    object
# ...

# %%
combined_df.to_csv('combined_vadodra.csv')
